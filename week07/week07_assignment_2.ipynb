# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# In the cell below, create a function called **parse_banner(url)** that takes as it's one parameter the URL of the webpage to be parsed for links.  Make sure you include docstrings and a good test case using hte URL provided above.

# %%
from bs4 import BeautifulSoup
import requests

# Note that you'll need to fetch the data using the following syntax to include headers
# that make the web server think you're a real web browser.
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }
response = requests.get(url, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4e29a8de60b6> in <module>
#       5 # that make the web server think you're a real web browser.
#       6 headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }
# ----> 7 response = requests.get(url, headers=headers)
#       8
#
# NameError: name 'url' is not defined

# %%
import doctest
doctest.run_docstring_examples(parse_banner, globals(), verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-23f2c2e2c347> in <module>
#       1 import doctest
# ----> 2 doctest.run_docstring_examples(parse_banner, globals(), verbose=True)
#
# NameError: name 'parse_banner' is not defined

# %%
banner = parse_banner('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency')
assert len(banner)==38, 'Length of result should have been 38, but {} returned.'.format(len(banner))
assert banner[0][1]=='Arizona', 'Wrong data found in the first result item: {}'.format(banner[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b50f7d3d19d6> in <module>
# ----> 1 banner = parse_banner('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency')
#       2 assert len(banner)==38, 'Length of result should have been 38, but {} returned.'.format(len(banner))
#       3 assert banner[0][1]=='Arizona', 'Wrong data found in the first result item: {}'.format(banner[0])
#
# NameError: name 'parse_banner' is not defined

# %% [markdown]
# ---
#
# ## 33.2 Using a REST API (from GitHub.com)
#
# Many websites provide something called a REST API to access information from their site programatically, rather than relying on HTML.  One example is GitHub.com, whose API allows you do to things like "list all the public repositories for a user."
#
# The documentation for GitHub.com's REST API can be found here: https://docs.github.com/en/rest/guides/getting-started-with-the-rest-api
#
# Create a function called **repo_summary(user)** that takes a GitHub.com user name as it's parameter and retrieves a list of all the repositories you can see for that user.  The specific documentation for the this kind of request can be found here: https://docs.github.com/en/rest/reference/repos#list-repositories-for-a-user. Make sure your function is well documented with a docstring and includes a simple test to verify that you get back 12 repositories when querying for the repositories for user **paulboal**.
#
# I've provided a related example to help you out.

# %%
# Example -- this example of code shows how to get basic information on the user paulboal
# For your solution, make sure you meet the requirements in the instructions above.


# Write a function that returns the "location" for any github user
import requests

def github_location(user):
    response = requests.get('https://api.github.com/users/'+user)
    data = response.json()
    location = data.get('location')
    return location

# %%
github_location('paulboal')
# Out:
# 'St. Louis, MO'

# %%
# Your code Here
import requests
'''Use the GitHub api to grab repos for a given user'''
def repo_summary(user):
    response=requests.get("https://api.github.com/users/" + user + "/repos")
    reposito
    return response.json()

# %%
repo_summary('paulboal')
# Out:
# [{'id': 47409566,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0NzQwOTU2Ng==',
#   'name': 'ajaxterm',
#   'full_name': 'paulboal/ajaxterm',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/ajaxterm',
#   'description': 'Patched copy of Ajaxterm that allows connecting to remote SSH servers',
#   'fork': True,
#   'url': 'https://api.github.com/repos/paulboal/ajaxterm',
#   'forks_url': 'https://api.github.com/repos/paulboal/ajaxterm/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/ajaxterm/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/ajaxterm/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/ajaxterm/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/ajaxterm/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/ajaxterm/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/ajaxterm/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/ajaxterm/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/ajaxterm/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/ajaxterm/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/ajaxterm/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/ajaxterm/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/ajaxterm/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/ajaxterm/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/ajaxterm/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/ajaxterm/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/ajaxterm/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/ajaxterm/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/ajaxterm/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/ajaxterm/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/ajaxterm/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/ajaxterm/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/ajaxterm/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/ajaxterm/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/ajaxterm/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/ajaxterm/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/ajaxterm/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/ajaxterm/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/ajaxterm/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/ajaxterm/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/ajaxterm/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/ajaxterm/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/ajaxterm/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/ajaxterm/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/ajaxterm/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/ajaxterm/deployments',
#   'created_at': '2015-12-04T14:44:52Z',
#   'updated_at': '2018-01-08T00:37:10Z',
#   'pushed_at': '2010-01-08T01:14:33Z',
#   'git_url': 'git://github.com/paulboal/ajaxterm.git',
#   'ssh_url': 'git@github.com:paulboal/ajaxterm.git',
#   'clone_url': 'https://github.com/paulboal/ajaxterm.git',
#   'svn_url': 'https://github.com/paulboal/ajaxterm',
#   'homepage': 'http://antony.lesuisse.org/software/ajaxterm/',
#   'size': 111,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 51697713,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MTY5NzcxMw==',
#   'name': 'cms_hospital_compare',
#   'full_name': 'paulboal/cms_hospital_compare',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/cms_hospital_compare',
#   'description': 'Hadoop Sandbox demo with CMS Hospital Compare data',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/cms_hospital_compare',
#   'forks_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/cms_hospital_compare/deployments',
#   'created_at': '2016-02-14T14:25:17Z',
#   'updated_at': '2016-02-15T17:58:34Z',
#   'pushed_at': '2016-02-18T14:51:01Z',
#   'git_url': 'git://github.com/paulboal/cms_hospital_compare.git',
#   'ssh_url': 'git@github.com:paulboal/cms_hospital_compare.git',
#   'clone_url': 'https://github.com/paulboal/cms_hospital_compare.git',
#   'svn_url': 'https://github.com/paulboal/cms_hospital_compare',
#   'homepage': None,
#   'size': 95,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 43384474,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MzM4NDQ3NA==',
#   'name': 'collibra-scripts',
#   'full_name': 'paulboal/collibra-scripts',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/collibra-scripts',
#   'description': 'Scripts (mostly Python) for automating tasks with the Collibra API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/collibra-scripts',
#   'forks_url': 'https://api.github.com/repos/paulboal/collibra-scripts/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/collibra-scripts/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/collibra-scripts/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/collibra-scripts/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/collibra-scripts/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/collibra-scripts/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/collibra-scripts/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/collibra-scripts/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/collibra-scripts/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/collibra-scripts/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/collibra-scripts/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/collibra-scripts/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/collibra-scripts/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/collibra-scripts/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/collibra-scripts/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/collibra-scripts/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/collibra-scripts/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/collibra-scripts/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/collibra-scripts/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/collibra-scripts/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/collibra-scripts/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/collibra-scripts/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/collibra-scripts/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/collibra-scripts/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/collibra-scripts/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/collibra-scripts/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/collibra-scripts/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/collibra-scripts/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/collibra-scripts/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/collibra-scripts/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/collibra-scripts/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/collibra-scripts/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/collibra-scripts/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/collibra-scripts/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/collibra-scripts/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/collibra-scripts/deployments',
#   'created_at': '2015-09-29T17:54:21Z',
#   'updated_at': '2020-08-21T12:39:20Z',
#   'pushed_at': '2015-09-29T18:02:17Z',
#   'git_url': 'git://github.com/paulboal/collibra-scripts.git',
#   'ssh_url': 'git@github.com:paulboal/collibra-scripts.git',
#   'clone_url': 'https://github.com/paulboal/collibra-scripts.git',
#   'svn_url': 'https://github.com/paulboal/collibra-scripts',
#   'homepage': None,
#   'size': 140,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'master'},
#  {'id': 248770943,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNDg3NzA5NDM=',
#   'name': 'coronadatascraper',
#   'full_name': 'paulboal/coronadatascraper',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/coronadatascraper',
#   'description': 'COVID-19 Coronavirus data scraped from government and curated data sources.',
#   'fork': True,
#   'url': 'https://api.github.com/repos/paulboal/coronadatascraper',
#   'forks_url': 'https://api.github.com/repos/paulboal/coronadatascraper/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/coronadatascraper/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/coronadatascraper/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/coronadatascraper/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/coronadatascraper/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/coronadatascraper/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/coronadatascraper/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/coronadatascraper/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/coronadatascraper/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/coronadatascraper/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/coronadatascraper/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/coronadatascraper/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/coronadatascraper/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/coronadatascraper/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/coronadatascraper/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/coronadatascraper/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/coronadatascraper/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/coronadatascraper/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/coronadatascraper/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/coronadatascraper/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/coronadatascraper/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/coronadatascraper/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/coronadatascraper/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/coronadatascraper/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/coronadatascraper/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/coronadatascraper/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/coronadatascraper/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/coronadatascraper/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/coronadatascraper/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/coronadatascraper/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/coronadatascraper/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/coronadatascraper/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/coronadatascraper/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/coronadatascraper/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/coronadatascraper/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/coronadatascraper/deployments',
#   'created_at': '2020-03-20T14:07:30Z',
#   'updated_at': '2020-04-01T20:00:11Z',
#   'pushed_at': '2020-04-01T20:00:07Z',
#   'git_url': 'git://github.com/paulboal/coronadatascraper.git',
#   'ssh_url': 'git@github.com:paulboal/coronadatascraper.git',
#   'clone_url': 'https://github.com/paulboal/coronadatascraper.git',
#   'svn_url': 'https://github.com/paulboal/coronadatascraper',
#   'homepage': 'https://coronadatascraper.com',
#   'size': 27466,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'JavaScript',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'bsd-2-clause',
#    'name': 'BSD 2-Clause "Simplified" License',
#    'spdx_id': 'BSD-2-Clause',
#    'url': 'https://api.github.com/licenses/bsd-2-clause',
#    'node_id': 'MDc6TGljZW5zZTQ='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 41012079,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTAxMjA3OQ==',
#   'name': 'hadoop-heuristicsminer',
#   'full_name': 'paulboal/hadoop-heuristicsminer',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/hadoop-heuristicsminer',
#   'description': 'The project implements the HeuristicsMiner process mining algorithm in Hadoop MapReduce.  See the README for additional information.',
#   'fork': True,
#   'url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer',
#   'forks_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/hadoop-heuristicsminer/deployments',
#   'created_at': '2015-08-19T03:50:54Z',
#   'updated_at': '2015-08-19T03:50:55Z',
#   'pushed_at': '2012-06-29T13:22:25Z',
#   'git_url': 'git://github.com/paulboal/hadoop-heuristicsminer.git',
#   'ssh_url': 'git@github.com:paulboal/hadoop-heuristicsminer.git',
#   'clone_url': 'https://github.com/paulboal/hadoop-heuristicsminer.git',
#   'svn_url': 'https://github.com/paulboal/hadoop-heuristicsminer',
#   'homepage': None,
#   'size': 444,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Java',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 530449547,
#   'node_id': 'R_kgDOH54Eiw',
#   'name': 'hds5210-2022',
#   'full_name': 'paulboal/hds5210-2022',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/hds5210-2022',
#   'description': 'Public repository for SLU HDS5210 Fall 2022',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/hds5210-2022',
#   'forks_url': 'https://api.github.com/repos/paulboal/hds5210-2022/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/hds5210-2022/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/hds5210-2022/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/hds5210-2022/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/hds5210-2022/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/hds5210-2022/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/hds5210-2022/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/hds5210-2022/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/hds5210-2022/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/hds5210-2022/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/hds5210-2022/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/hds5210-2022/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/hds5210-2022/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/hds5210-2022/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/hds5210-2022/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/hds5210-2022/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/hds5210-2022/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/hds5210-2022/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/hds5210-2022/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/hds5210-2022/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/hds5210-2022/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/hds5210-2022/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/hds5210-2022/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/hds5210-2022/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/hds5210-2022/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/hds5210-2022/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/hds5210-2022/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/hds5210-2022/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/hds5210-2022/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/hds5210-2022/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/hds5210-2022/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/hds5210-2022/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/hds5210-2022/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/hds5210-2022/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/hds5210-2022/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/hds5210-2022/deployments',
#   'created_at': '2022-08-30T01:08:04Z',
#   'updated_at': '2022-09-06T02:31:19Z',
#   'pushed_at': '2022-09-23T01:47:03Z',
#   'git_url': 'git://github.com/paulboal/hds5210-2022.git',
#   'ssh_url': 'git@github.com:paulboal/hds5210-2022.git',
#   'clone_url': 'https://github.com/paulboal/hds5210-2022.git',
#   'svn_url': 'https://github.com/paulboal/hds5210-2022',
#   'homepage': None,
#   'size': 12,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 44,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 44,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 540221954,
#   'node_id': 'R_kgDOIDMiAg',
#   'name': 'hds5210-2022t',
#   'full_name': 'paulboal/hds5210-2022t',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/hds5210-2022t',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/hds5210-2022t',
#   'forks_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/hds5210-2022t/deployments',
#   'created_at': '2022-09-23T00:40:17Z',
#   'updated_at': '2022-09-23T00:43:57Z',
#   'pushed_at': '2022-09-23T00:52:15Z',
#   'git_url': 'git://github.com/paulboal/hds5210-2022t.git',
#   'ssh_url': 'git@github.com:paulboal/hds5210-2022t.git',
#   'clone_url': 'https://github.com/paulboal/hds5210-2022t.git',
#   'svn_url': 'https://github.com/paulboal/hds5210-2022t',
#   'homepage': None,
#   'size': 3,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 156571814,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNTY1NzE4MTQ=',
#   'name': 'jupyterhub-nbgrader',
#   'full_name': 'paulboal/jupyterhub-nbgrader',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/jupyterhub-nbgrader',
#   'description': 'Reference deployment of JupyterHub with docker',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader',
#   'forks_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/jupyterhub-nbgrader/deployments',
#   'created_at': '2018-11-07T15:59:45Z',
#   'updated_at': '2021-05-01T10:52:39Z',
#   'pushed_at': '2018-11-07T16:03:11Z',
#   'git_url': 'git://github.com/paulboal/jupyterhub-nbgrader.git',
#   'ssh_url': 'git@github.com:paulboal/jupyterhub-nbgrader.git',
#   'clone_url': 'https://github.com/paulboal/jupyterhub-nbgrader.git',
#   'svn_url': 'https://github.com/paulboal/jupyterhub-nbgrader',
#   'homepage': None,
#   'size': 373,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 52116176,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MjExNjE3Ng==',
#   'name': 'nppes_demo',
#   'full_name': 'paulboal/nppes_demo',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/nppes_demo',
#   'description': 'Loading NPPES data into Hadoop for search',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/nppes_demo',
#   'forks_url': 'https://api.github.com/repos/paulboal/nppes_demo/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/nppes_demo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/nppes_demo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/nppes_demo/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/nppes_demo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/nppes_demo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/nppes_demo/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/nppes_demo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/nppes_demo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/nppes_demo/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/nppes_demo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/nppes_demo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/nppes_demo/git/refs{/sha}',
# ...
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/pexpect-curses',
#   'forks_url': 'https://api.github.com/repos/paulboal/pexpect-curses/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/pexpect-curses/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/pexpect-curses/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/pexpect-curses/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/pexpect-curses/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/pexpect-curses/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/pexpect-curses/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/pexpect-curses/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/pexpect-curses/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/pexpect-curses/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/pexpect-curses/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/pexpect-curses/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/pexpect-curses/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/pexpect-curses/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/pexpect-curses/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/pexpect-curses/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/pexpect-curses/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/pexpect-curses/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/pexpect-curses/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/pexpect-curses/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/pexpect-curses/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/pexpect-curses/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/pexpect-curses/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/pexpect-curses/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/pexpect-curses/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/pexpect-curses/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/pexpect-curses/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/pexpect-curses/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/pexpect-curses/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/pexpect-curses/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/pexpect-curses/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/pexpect-curses/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/pexpect-curses/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/pexpect-curses/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/pexpect-curses/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/pexpect-curses/deployments',
#   'created_at': '2015-12-07T15:53:20Z',
#   'updated_at': '2018-08-09T22:17:41Z',
#   'pushed_at': '2015-12-16T20:06:55Z',
#   'git_url': 'git://github.com/paulboal/pexpect-curses.git',
#   'ssh_url': 'git@github.com:paulboal/pexpect-curses.git',
#   'clone_url': 'https://github.com/paulboal/pexpect-curses.git',
#   'svn_url': 'https://github.com/paulboal/pexpect-curses',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 2,
#   'watchers': 2,
#   'default_branch': 'master'},
#  {'id': 46817255,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0NjgxNzI1NQ==',
#   'name': 'scm-products',
#   'full_name': 'paulboal/scm-products',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/scm-products',
#   'description': 'Supply Chain Project',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/scm-products',
#   'forks_url': 'https://api.github.com/repos/paulboal/scm-products/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/scm-products/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/scm-products/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/scm-products/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/scm-products/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/scm-products/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/scm-products/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/scm-products/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/scm-products/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/scm-products/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/scm-products/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/scm-products/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/scm-products/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/scm-products/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/scm-products/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/scm-products/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/scm-products/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/scm-products/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/scm-products/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/scm-products/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/scm-products/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/scm-products/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/scm-products/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/scm-products/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/scm-products/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/scm-products/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/scm-products/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/scm-products/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/scm-products/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/scm-products/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/scm-products/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/scm-products/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/scm-products/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/scm-products/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/scm-products/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/scm-products/deployments',
#   'created_at': '2015-11-24T20:39:05Z',
#   'updated_at': '2015-11-24T20:51:28Z',
#   'pushed_at': '2015-11-24T21:13:57Z',
#   'git_url': 'git://github.com/paulboal/scm-products.git',
#   'ssh_url': 'git@github.com:paulboal/scm-products.git',
#   'clone_url': 'https://github.com/paulboal/scm-products.git',
#   'svn_url': 'https://github.com/paulboal/scm-products',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 104674355,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDQ2NzQzNTU=',
#   'name': 'tdwi-accelerate-2017-python',
#   'full_name': 'paulboal/tdwi-accelerate-2017-python',
#   'private': False,
#   'owner': {'login': 'paulboal',
#    'id': 1817916,
#    'node_id': 'MDQ6VXNlcjE4MTc5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1817916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulboal',
#    'html_url': 'https://github.com/paulboal',
#    'followers_url': 'https://api.github.com/users/paulboal/followers',
#    'following_url': 'https://api.github.com/users/paulboal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulboal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulboal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulboal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulboal/orgs',
#    'repos_url': 'https://api.github.com/users/paulboal/repos',
#    'events_url': 'https://api.github.com/users/paulboal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulboal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paulboal/tdwi-accelerate-2017-python',
#   'description': 'Code and materials for the TDWI Accelerate 2017 Python Quick Camp',
#   'fork': False,
#   'url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python',
#   'forks_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/forks',
#   'keys_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/teams',
#   'hooks_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/events',
#   'assignees_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/tags',
#   'blobs_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/subscription',
#   'commits_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/merges',
#   'archive_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/downloads',
#   'issues_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paulboal/tdwi-accelerate-2017-python/deployments',
#   'created_at': '2017-09-24T20:32:59Z',
#   'updated_at': '2022-08-17T18:51:44Z',
#   'pushed_at': '2017-10-17T20:43:50Z',
#   'git_url': 'git://github.com/paulboal/tdwi-accelerate-2017-python.git',
#   'ssh_url': 'git@github.com:paulboal/tdwi-accelerate-2017-python.git',
#   'clone_url': 'https://github.com/paulboal/tdwi-accelerate-2017-python.git',
#   'svn_url': 'https://github.com/paulboal/tdwi-accelerate-2017-python',
#   'homepage': None,
#   'size': 33133,
#   'stargazers_count': 4,
#   'watchers_count': 4,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 4,
#   'default_branch': 'master'}]

# %%
test= repo_summary("paulboal")
print(len(test))#
# Out:
# 12

# %%
import doctest
doctest.run_docstring_examples(repo_summary, globals(), verbose=True)
# Out:
# Finding tests in NoName

# %%
repos = repo_summary('paulboal')
assert len(repos)==12, 'Expecing 12, but {} were found'.format(len(repos))

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# First run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Then open a new command line by clicking the `+` icon above the file list and chosing `Terminal`
# 3. At the command line in the new Terminal, follow these steps:
#   1. Change directories to your project folder and the week03 subfolder (`cd <folder name>`)
#   2. Make sure your project folders are up to date with github.com (`git pull`)
#   3. Add the homework files for this week (`git add <file name>`)
#   4. Commit your changes (`git commit -a -m "message"`)
#   5. Push your changes (`git push`)
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.
